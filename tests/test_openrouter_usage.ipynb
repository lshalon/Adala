# %%
from adala.runtimes import (
    LiteLLMChatRuntime,
)

# %%
from adala.runtimes import OpenAIChatRuntime

# %%
from adala.runtimes import OpenRouterChatRuntime

# %%
OpenRouterChatRuntime(
    model="anthropic/claude-3.5-haiku-20241022:beta",
    api_key="xxx"
).get_llm_response(
    messages=[
        {
            "role": "user",
            "content": "return the word Banana with exclamation mark"
        }
    ]
)
# Out:
# 'Here\'s the word "Banana" with an exclamation mark:\n\nBanana!'

# %%
OpenAIChatRuntime().get_llm_response(
    messages=[
        {
            "role": "user",
            "content": "return the word Banana with exclamation mark"
        }
    ]
)
# Out:
# Failed to check availability of requested model "gpt-4o-mini": litellm.AuthenticationError: AuthenticationError: OpenAIException - The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable
# Traceback:
# Traceback (most recent call last):
#   File "/Users/liam/Documents/Level/Adala/.venv/lib/python3.10/site-packages/litellm/llms/openai/openai.py", line 726, in completion
#     raise e
#   File "/Users/liam/Documents/Level/Adala/.venv/lib/python3.10/site-packages/litellm/llms/openai/openai.py", line 629, in completion
#     openai_client: OpenAI = self._get_openai_client(  # type: ignore
#   File "/Users/liam/Documents/Level/Adala/.venv/lib/python3.10/site-packages/litellm/llms/openai/openai.py", line 378, in _get_openai_client
#     _new_client = OpenAI(
#   File "/Users/liam/Documents/Level/Adala/.venv/lib/python3.10/site-packages/openai/_client.py", line 114, in __init__
#     raise OpenAIError(
# ...

# %%
from adala.runtimes import LiteLLMChatRuntime
LiteLLMChatRuntime().get_llm_response(
    messages=[
        {
            "role": "user",
            "content": "return the word Banana with exclamation mark"
        }
    ]
)
# Out:
# Failed to check availability of requested model "gpt-4o-mini": litellm.AuthenticationError: AuthenticationError: OpenAIException - The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable
# Traceback:
# Traceback (most recent call last):
#   File "/Users/liam/Documents/Level/Adala/.venv/lib/python3.10/site-packages/litellm/llms/openai/openai.py", line 726, in completion
#     raise e
#   File "/Users/liam/Documents/Level/Adala/.venv/lib/python3.10/site-packages/litellm/llms/openai/openai.py", line 629, in completion
#     openai_client: OpenAI = self._get_openai_client(  # type: ignore
#   File "/Users/liam/Documents/Level/Adala/.venv/lib/python3.10/site-packages/litellm/llms/openai/openai.py", line 378, in _get_openai_client
#     _new_client = OpenAI(
#   File "/Users/liam/Documents/Level/Adala/.venv/lib/python3.10/site-packages/openai/_client.py", line 114, in __init__
#     raise OpenAIError(
# ...

# %%
LiteLLMChatRuntime().get_llm_response(
    messages=[
        {
            "role": "user",
            "content": "return the word Banana with exclamation mark"
        }
    ]
)
# Out:
# Failed to check availability of requested model "gpt-4o-mini": litellm.AuthenticationError: AuthenticationError: OpenAIException - The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable
# Traceback:
# Traceback (most recent call last):
#   File "/Users/liam/Documents/Level/Adala/.venv/lib/python3.10/site-packages/litellm/llms/openai/openai.py", line 726, in completion
#     raise e
#   File "/Users/liam/Documents/Level/Adala/.venv/lib/python3.10/site-packages/litellm/llms/openai/openai.py", line 629, in completion
#     openai_client: OpenAI = self._get_openai_client(  # type: ignore
#   File "/Users/liam/Documents/Level/Adala/.venv/lib/python3.10/site-packages/litellm/llms/openai/openai.py", line 378, in _get_openai_client
#     _new_client = OpenAI(
#   File "/Users/liam/Documents/Level/Adala/.venv/lib/python3.10/site-packages/openai/_client.py", line 114, in __init__
#     raise OpenAIError(
# ...
